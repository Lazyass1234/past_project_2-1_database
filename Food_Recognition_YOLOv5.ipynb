# %% [markdown]
# <a href="https://colab.research.google.com/github/Lazyass1234/past_projects/blob/main/Food_Recognition_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install Yolo requirements
# https://github.com/ultralytics/yolov5
# !git clone https://github.com/ultralytics/yolov5  # clone
# !cd yolov5
# !pip install -r yolov5/requirements.txt  # install

# %%
# dataset source    images are not the same
# https://app.activeloop.ai/sainikhileshreddy/food-recognition-2022-train
# https://app.activeloop.ai/sainikhileshreddy/food-recognition-2022-val
# https://app.activeloop.ai/sainikhileshreddy/food-recognition-2022-test
# !pip install hub
import hub
ds_train = hub.load('hub://sainikhileshreddy/food-recognition-2022-train')  #3915
ds_val = hub.load('hub://sainikhileshreddy/food-recognition-2022-val')      #1000
ds_test = hub.load('hub://sainikhileshreddy/food-recognition-2022-test')    #3000

# %%
ds_train.summary()
ds_val.summary()
ds_test.summary()
# Out:
# Dataset(path='hub://sainikhileshreddy/food-recognition-2022-train', read_only=True, tensors=['images', 'images_meta', 'masks', 'boxes', 'categories', 'super_categories', 'areas', 'iscrowds'])
#
#       tensor          htype              shape             dtype  compression
#      -------         -------            -------           -------  -------
#       images          image      (3915, None, None, 3)     uint8    jpeg
#    images_meta        json             (3914, 1)            str     None
#       masks        binary_mask  (3914, None, None, None)   bool      lz4
#       boxes           bbox          (3914, None, 4)       float32   None
#     categories     class_label        (3914, None)        uint32    None
#  super_categories  class_label        (3914, None)        uint32    None
#       areas          generic          (3914, None)        uint32    None
#      iscrowds        generic          (3914, None)         bool     None
# ...

# %%
#ds_val['images_meta'][999]
ds_val.images_meta.numpy()
# Out:
# array([[{'id': 7954, 'file_name': '007954.jpg', 'width': 480, 'height': 480}],
#        [{'id': 7955, 'file_name': '007955.jpg', 'width': 426, 'height': 426}],
#        [{'id': 8082, 'file_name': '008082.jpg', 'width': 480, 'height': 480}],
#        [{'id': 8108, 'file_name': '008108.jpg', 'width': 480, 'height': 480}],
#        [{'id': 8135, 'file_name': '008135.jpg', 'width': 480, 'height': 480}],
#        [{'id': 8536, 'file_name': '008536.jpg', 'width': 480, 'height': 480}],
#        [{'id': 8813, 'file_name': '008813.jpg', 'width': 853, 'height': 853}],
#        [{'id': 9260, 'file_name': '009260.jpg', 'width': 479, 'height': 479}],
#        [{'id': 10757, 'file_name': '010757.jpg', 'width': 943, 'height': 943}],
#        [{'id': 10799, 'file_name': '010799.jpg', 'width': 479, 'height': 479}],
#        [{'id': 11275, 'file_name': '011275.jpg', 'width': 480, 'height': 480}],
#        [{'id': 14043, 'file_name': '014043.jpg', 'width': 479, 'height': 479}],
# ...

# %%
# !cd yolov5
# !python train.py --data coco128.yaml --weights '' --cfg yolov5s.yaml --img 480
# Out:
# sample_data  yolov5  yolov5s.pt

# %%
# After I train the model
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Pytorch dataloader
# https://docs.activeloop.ai/getting-started/connecting-to-ml-frameworks#pytorch
train_ds_loader = ds_train.pytorch(batch_size=16,
                                   num_workers=2,
                                   transform={},
                                   shuffle=True)
